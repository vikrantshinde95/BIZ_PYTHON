# %%
import pandas as pd
import numpy as np

# %%
ca_df = pd.read_csv("CAvideos.csv")
ca_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
ca_df.shape
# Out:
# (2199, 16)

# %%
de_df = pd.read_csv("DEvideos.csv")
de_df.head()
# Out:
#       video_id trending_date  \
# 0  LgVi6y5QIjM      17.14.11
# 1  Bayt7uQith4      17.14.11
# 2  1ZAPwfrtAFY      17.14.11
# 3  AHtypnRk7JE      17.14.11
# 4  ZJ9We4bjcg0      17.14.11
#
#                                                title            channel_title  \
# 0  Sing zu Ende! | Gesangseinlagen vom Feinsten |...                inscope21
# 1  Kinder ferngesteuert im Kiosk! Erwachsene abzo...  LUKE! Die Woche und ich
# 2  The Trump Presidency: Last Week Tonight with J...          LastWeekTonight
# 3                                Das Fermi-Paradoxon        100SekundenPhysik
# 4           18 SONGS mit Kelly MissesVlog (Sing-off)                     rezo
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:08:49.000Z
# 1           23  2017-11-12T22:30:01.000Z
# 2           24  2017-11-13T07:30:00.000Z
# 3           27  2017-11-12T15:00:01.000Z
# 4           24  2017-11-12T13:10:36.000Z
#
# ...

# %%
fr_df = pd.read_csv("FRvideos.csv")
fr_df.head()
# Out:
#       video_id trending_date  \
# 0  Ro6eob0LrCY      17.14.11
# 1  Yo84eqYwP98      17.14.11
# 2  ceqntSXE-10      17.14.11
# 3  WuTFI5qftCE      17.14.11
# 4  ee6OFs8TdEg      17.14.11
#
#                                                title        channel_title  \
# 0           Malika LePen : Femme de Gauche - Trailer  Le Raptor Dissident
# 1  LA PIRE PARTIE ft Le Rire Jaune, Pierre Croce,...              Le Labo
# 2  DESSINS ANIMÉS FRANÇAIS VS RUSSES 2 - Daniil...      Daniil le Russe
# 3                    PAPY GRENIER - METAL GEAR SOLID    Joueur Du Grenier
# 4  QUI SAUTERA LE PLUS HAUT ? (VÉLO SKATE ROLLER ...    Aurelien Fontenoy
#
#    category_id              publish_time  \
# 0           24  2017-11-13T17:32:55.000Z
# 1           24  2017-11-12T15:00:02.000Z
# 2           23  2017-11-13T17:00:38.000Z
# 3           20  2017-11-12T17:00:02.000Z
# 4           17  2017-11-13T16:30:03.000Z
#
#                                                 tags   views  likes  dislikes  \
# ...

# %%
gb_df = pd.read_csv("GBvideos.csv", on_bad_lines="skip")
gb_df.head()
# Out:
#       video_id                                              title  \
# 0  jt2OHQh0HoQ  Live Apple Event - Apple September Event 2017 ...
# 1  AqokkXoa7uE  Holly and Phillip Meet Samantha the Sex Robot ...
# 2  YPVcg45W0z4                    My DNA Test Results! I'm WHAT?!
# 3  T_PuZBdT2iM  getting into a conversation in a language you ...
# 4  NsjsmgmbCfc                               Baby Name Challenge!
#
#        channel_title  category_id  \
# 0        Apple Event           28
# 1       This Morning           24
# 2       emmablackery           24
# 3              ProZD            1
# 4  Sprinkleofglitter           26
#
#                                                 tags    views  likes  \
# 0  apple events|apple event|iphone 8|iphone x|iph...  7426393  78240
# 1  this morning|interview|holly willoughby|philli...   494203   2651
# 2  emmablackery|emma blackery|emma|blackery|briti...   142819  13119
# 3  skit|korean|language|conversation|esl|japanese...  1580028  65729
# ...

# %%
gb_df.shape
# Out:
# (7993, 11)

# %%
us_df = pd.read_csv("USvideos.csv")
us_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
us_df.shape
# Out:
# (2200, 16)

# %%
pd.concat([ca_df,de_df,fr_df,gb_df,us_df], axis=0)
# Out:
#          video_id trending_date  \
# 0     n1WpP7iowLc      17.14.11
# 1     0dBIkQ4Mz1M      17.14.11
# 2     5qpjK5DgCt4      17.14.11
# 3     d380meD0W0M      17.14.11
# 4     2Vv-BfVoq4g      17.14.11
# ...           ...           ...
# 2195  88kkrRv1UgI      17.24.11
# 2196  dcipHnWcB0w      17.24.11
# 2197  wJh-jurxmGQ      17.24.11
# 2198  JLOFZoBJnd8      17.24.11
# 2199  16W7c0mb-rE      17.24.11
#
#                                                   title  \
# 0            Eminem - Walk On Water (Audio) ft. Beyoncé
# 1                         PLUSH - Bad Unboxing Fan Mail
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                              I Dare You: GOING BALD!?
# 4           Ed Sheeran - Perfect (Official Music Video)
# ...                                                 ...
# 2195  What Happens to You if You Upload Your Mind to...
# 2196  Kim Kardashian's Surrogate Didn't Know Whose B...
# 2197  Will Ferrell Left Speechless as Mark Wahlberg ...
# ...

# %%
pd.concat([ca_df,de_df,fr_df,gb_df,us_df], axis=1)
# Out:
#          video_id trending_date  \
# 0     n1WpP7iowLc      17.14.11
# 1     0dBIkQ4Mz1M      17.14.11
# 2     5qpjK5DgCt4      17.14.11
# 3     d380meD0W0M      17.14.11
# 4     2Vv-BfVoq4g      17.14.11
# ...           ...           ...
# 7988          NaN           NaN
# 7989          NaN           NaN
# 7990          NaN           NaN
# 7991          NaN           NaN
# 7992          NaN           NaN
#
#                                                   title channel_title  \
# 0            Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                         PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2     Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                              I Dare You: GOING BALD!?      nigahiga
# 4           Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
# ...                                                 ...           ...
# 7988                                                NaN           NaN
# ...

# %%
pd.merge(ca_df,de_df, on=["title","category_id","tags"])
# Out:
#       video_id_x trending_date_x  \
# 0    n1WpP7iowLc        17.14.11
# 1    0dBIkQ4Mz1M        17.14.11
# 2    0dBIkQ4Mz1M        17.14.11
# 3    0dBIkQ4Mz1M        17.14.11
# 4    5qpjK5DgCt4        17.14.11
# ..           ...             ...
# 905  hPHffFAogVM        17.24.11
# 906  fDGWi4eUjRY        17.24.11
# 907  J2I_UvRpCf0        17.24.11
# 908  YdusEV-W9X8        17.24.11
# 909  3LK3AlnUvYM        17.24.11
#
#                                                  title      channel_title_x  \
# 0           Eminem - Walk On Water (Audio) ft. Beyoncé           EminemVEVO
# 1                        PLUSH - Bad Unboxing Fan Mail            iDubbbzTV
# 2                        PLUSH - Bad Unboxing Fan Mail            iDubbbzTV
# 3                        PLUSH - Bad Unboxing Fan Mail            iDubbbzTV
# 4    Racist Superman | Rudy Mancuso, King Bach & Le...         Rudy Mancuso
# ..                                                 ...                  ...
# ...

# %%
ca_df.join(fr_df, on = "title")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 ca_df.join(fr_df, on = "title")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:10757, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10747     if how == "cross":
#   10748         return merge(
#   10749             self,
#   10750             other,
#    (...)
#   10755             validate=validate,
#   10756         )
# > 10757     return merge(
#   10758         self,
#   10759         other,
#   10760         left_on=on,
#   10761         how=how,
#   10762         left_index=on is None,
#   10763         right_index=True,
#   10764         suffixes=(lsuffix, rsuffix),
#   10765         sort=sort,
#   10766         validate=validate,
#   10767     )
#   10768 else:
#   10769     if on is not None:
#
# ...

# %%
## READING A JASON FILE

ca_json = pd.read_json("CA_category_id.json")
de_json = pd.read_json("DE_category_id.json")
fr_json = pd.read_json("FR_category_id.json")
gb_json = pd.read_json("GB_category_id.json")
us_json = pd.read_json("US_category_id.json")

# %%
ca_json.head()
# Out:
#                                 kind  \
# 0  youtube#videoCategoryListResponse
# 1  youtube#videoCategoryListResponse
# 2  youtube#videoCategoryListResponse
# 3  youtube#videoCategoryListResponse
# 4  youtube#videoCategoryListResponse
#
#                                                 etag  \
# 0  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 1  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 2  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 3  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
# 4  "ld9biNPKjAjgjV7EZ4EKeEGrhao/1v2mrzYSYG6onNLt2...
#
#                                                items
# 0  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 1  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 2  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 3  {'kind': 'youtube#videoCategory', 'etag': '"ld...
# 4  {'kind': 'youtube#videoCategory', 'etag': '"ld...

# %%
ca_json["items"][2]
# Out:
# {'kind': 'youtube#videoCategory',
#  'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxbknKFVe5Lmg"',
#  'id': '10',
#  'snippet': {'channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'title': 'Music',
#   'assignable': True}}

# %%
ca_json["items"][2]["id"]
# Out:
# '10'

# %%
ca_json["items"][2]["snippet"]["title"]
# Out:
# 'Music'

# %%
ca_json["items"][2]["kind"]
# Out:
# 'youtube#videoCategory'

# %%
for id in ca_json["items"]:
    print(f"id : {ca_json["items"]["id"]["kind"]} and title : {ca_json["items"]["id"]["title"]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[71], line 2
#       1 for id in ca_json["items"]:
# ----> 2     print(f"id : {ca_json["items"]["id"]["kind"]} and title : {ca_json["items"]["id"]["title"]}")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# ...

# %%
for i in ca_json["items"]:
    print("id: ",i["id"], "||", "kind: " ,i["kind"], "||", "title : ", i["snippet"]["title"])
# Out:
# id:  1 || kind:  youtube#videoCategory || title :  Film & Animation
# id:  2 || kind:  youtube#videoCategory || title :  Autos & Vehicles
# id:  10 || kind:  youtube#videoCategory || title :  Music
# id:  15 || kind:  youtube#videoCategory || title :  Pets & Animals
# id:  17 || kind:  youtube#videoCategory || title :  Sports
# id:  18 || kind:  youtube#videoCategory || title :  Short Movies
# id:  19 || kind:  youtube#videoCategory || title :  Travel & Events
# id:  20 || kind:  youtube#videoCategory || title :  Gaming
# id:  21 || kind:  youtube#videoCategory || title :  Videoblogging
# id:  22 || kind:  youtube#videoCategory || title :  People & Blogs
# id:  23 || kind:  youtube#videoCategory || title :  Comedy
# id:  24 || kind:  youtube#videoCategory || title :  Entertainment
# id:  25 || kind:  youtube#videoCategory || title :  News & Politics
# id:  26 || kind:  youtube#videoCategory || title :  Howto & Style
# id:  27 || kind:  youtube#videoCategory || title :  Education
# ...

# %%
ca_json["items"][2]["kind"]
# Out:
# 'youtube#videoCategory'

# %%
count = 0
l1 = []

for i in dfa["items"]:
    dfname = f"items_{count}"
    globals()[dfname]=pd.DataFrame(i)
    l1.append(dfname)
    coynt+=1

# %%
import json
import pandas as pd

with open("CA_category_id.json","r") as json_data:
    data = json.load(json_data)

# %%
normalized_data = pd.json_normalize(data["items"])

# %%
df_new = pd.DataFrame(normalized_data)
df_new
# Out:
#                      kind                                               etag  \
# 0   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...
# 1   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...
# 2   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...
# 3   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...
# 4   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...
# 5   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/FJwVpGCVZ1yiJrqZb...
# 6   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/M-3iD9dwK7YJCafRf...
# 7   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WmA0qYEfjWsAoyJFS...
# 8   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EapFaGYG7K0StIXVf...
# 9   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/xId8RX7vRN8rqkbYZ...
# 10  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/G9LHzQmx44rX2S5ya...
# ...

# %%
new_merge = pd.concat([df_new,ca_df],axis=1)
new_merge.head(32)
# Out:
#                      kind                                               etag  \
# 0   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/Xy1mB4_yLrHy_BmKm...
# 1   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/UZ1oLIIz2dxIhO45Z...
# 2   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/nqRIq97-xe5XRZTxb...
# 3   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/HwXKamM1Q20q9BN-o...
# 4   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/9GQMSRjrZdHeb1OEM...
# 5   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/FJwVpGCVZ1yiJrqZb...
# 6   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/M-3iD9dwK7YJCafRf...
# 7   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/WmA0qYEfjWsAoyJFS...
# 8   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/EapFaGYG7K0StIXVf...
# 9   youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/xId8RX7vRN8rqkbYZ...
# 10  youtube#videoCategory  "ld9biNPKjAjgjV7EZ4EKeEGrhao/G9LHzQmx44rX2S5ya...
# ...

# %%
type(normalized_data)
# Out:
# pandas.core.frame.DataFrame
