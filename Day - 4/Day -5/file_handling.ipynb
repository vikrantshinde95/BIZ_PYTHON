# %%
open(r"C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON\Day -5.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 open(r"C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON\Day -5.txt")
#
# File c:\Program Files\Python313\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Lenovo\\OneDrive\\Desktop\\BIZ_PYTHON\\Day -5.txt'

# %%
open(r"C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON\Day -5\first.txt")
# Out:
# <_io.TextIOWrapper name='C:\\Users\\Lenovo\\OneDrive\\Desktop\\BIZ_PYTHON\\Day -5\\first.txt' mode='r' encoding='cp1252'>

# %%
print(help(open))
# Out:
# Help on function open in module _io:
#
# open(
#     file,
#     mode='r',
#     buffering=-1,
#     encoding=None,
#     errors=None,
#     newline=None,
#     closefd=True,
#     opener=None
# )
#     Open file and return a stream.  Raise OSError upon failure.
#
#     file is either a text or byte string giving the name (and the path
#     if the file isn't in the current working directory) of the file to
#     be opened or an integer file descriptor of the file to be
#     wrapped. (If a file descriptor is given, it is closed when the
#     returned I/O object is closed, unless closefd is set to False.)
#
#     mode is an optional string that specifies the mode in which the file
#     is opened. It defaults to 'r' which means open for reading in text
#     mode.  Other common values are 'w' for writing (truncating the file if
#     it already exists), 'x' for creating and writing to a new file, and
#     'a' for appending (which on some Unix systems, means that all writes
# ...

# %%
import matplotlib.image as mping
import matplotlib.pyplot as plt

# %%
data  = r"C:\Users\Lenovo\OneDrive\Desktop\planet-earth-with-sunrise-in-space-photo.jpg"
data
# Out:
# 'C:\\Users\\Lenovo\\OneDrive\\Desktop\\planet-earth-with-sunrise-in-space-photo.jpg'

# %%
img = mping.imread(data)
print(type(img))
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>

# %%
from PIL import Image

# %%
data  = r"C:\Users\Lenovo\OneDrive\Desktop\planet-earth-with-sunrise-in-space-photo.jpg"
data
# Out:
# 'C:\\Users\\Lenovo\\OneDrive\\Desktop\\planet-earth-with-sunrise-in-space-photo.jpg'

# %%
img2 = Image.open(data)

# %%
img2.show()

# %%
import os
l1 = os.listdir(r"C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON")

# %%
for i in l1:
    print(i)
# Out:
# .git
# .gitattributes
# Day - 4
# Day -3
# Day -5
# DAY-1
# DAY-2

# %%
import os
for i in os.listdir("D:\\Bizmetric\\Day -5"):
    filename = "D:\\Bizmetric\Day -5\\" + i
    # print(filename)
    sz = os.stat(filename).st_size/1000

    print(filename, sz,"kb")
# Out:
# D:\Bizmetric\Day -5\file_handling.ipynb 0.0 kb
# D:\Bizmetric\Day -5\first.txt 0.154 kb
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_35044\3906111115.py:3: SyntaxWarning: invalid escape sequence '\D'
#   filename = "D:\\Bizmetric\Day -5\\" + i

# %%
# print(os.listdir("D:\Bizmetric\Day -5"))
# Out:
# ['file_handling.ipynb', 'first.txt']
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_35044\4232868219.py:1: SyntaxWarning: invalid escape sequence '\B'
#   print(os.listdir("D:\Bizmetric\Day -5"))

# %%
import os
for i in os.listdir("C:\\Users\\Lenovo\\OneDrive\\Desktop\\BIZ_PYTHON\\DAY-2\\"):
    filename = "C:\\Users\\Lenovo\\OneDrive\\Desktop\\BIZ_PYTHON\\DAY-2\\" + i
    # print(filename)
    sz = os.stat(filename).st_size/1000

    print(filename, sz,"kb")
# Out:
# C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON\DAY-2\bill.ipynb 0.0 kb
# C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON\DAY-2\bill_new.ipynb 4.373 kb
# C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON\DAY-2\decorators.ipynb 0.0 kb
# C:\Users\Lenovo\OneDrive\Desktop\BIZ_PYTHON\DAY-2\regex.ipynb 23.345 kb

# %%
import shutil

# %%
shutil.copy("C:\\Users\\Lenovo\\OneDrive\\Desktop\\BIZ_PYTHON\\Day -5\\first.txt", "D:\\Bizmetric\\Day -5")
# Out:
# 'D:\\Bizmetric\\Day -5\\first.txt'

# %%
shutil.move("C:\\Users\\Lenovo\\OneDrive\\Desktop\\planet-earth-with-sunrise-in-space-photo.jpg", "D:\\Bizmetric\\Day -5" )
# Out:
# 'D:\\Bizmetric\\Day -5\\planet-earth-with-sunrise-in-space-photo.jpg'

# %%
shutil.copytree("C:\\Users\\Lenovo\\OneDrive\\Desktop\\BIZ_PYTHON\\DAY-2","D:\\Bizmetric\\Day -5")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 shutil.copytree("C:\\Users\\Lenovo\\OneDrive\\Desktop\\BIZ_PYTHON\\DAY-2","D:\\Bizmetric\\Day -5")
#
# File c:\Program Files\Python313\Lib\shutil.py:593, in copytree(src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     591 with os.scandir(src) as itr:
#     592     entries = list(itr)
# --> 593 return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#     594                  ignore=ignore, copy_function=copy_function,
#     595                  ignore_dangling_symlinks=ignore_dangling_symlinks,
#     596                  dirs_exist_ok=dirs_exist_ok)
#
# File c:\Program Files\Python313\Lib\shutil.py:491, in _copytree(entries, src, dst, symlinks, ignore, copy_function, ignore_dangling_symlinks, dirs_exist_ok)
#     488 else:
# ...

# %%
shutil.copytree("D:\\folder_1\\31_1_2023_Variables","D:\\Bizmetric\\Day -5\\ABCD")
# Out:
# 'D:\\Bizmetric\\Day -5\\ABCD'

# %%
f = open(r"D:\Bizmetric\Day -5\abc_d.txt", "x")

# %%
print("---------------- Start-----------------")
f.write("This is the file handling technique\n")
f.write("BBBDGHDJJ\n")
f.write("writing file is interesting\n")
f.close()
# Out:
# ---------------- Start-----------------

# %%
f = open(r"D:\Bizmetric\Day -5\abc_d.txt", "w")

# %%
print("-------------------------------------------")
f.write("this is in write mode\n")
f.write("welcome\n")
f.close()
# Out:
# -------------------------------------------

# %%
f = open(r"D:\Bizmetric\Day -5\abc_d.txt", "a")

# %%
print("____-----------------------------------______________________\n")
f.write("ZZZZZZZZZZZZZZZZZZZZZZZZZZZZZ\n")
f.write("END!")
f.close()
# Out:
# ____-----------------------------------______________________

# %%
f = open(r"D:\Bizmetric\Day -5\abc_d.txt")


while True:
    str1 = f.readline()
    print("position in loop = ", f.tell())
    if str1:
        print(str1)
    else:
        break

print("-----------------------------------------------------------")
f.seek(7)
print("current position = ",f.tell())
print(f.read())
# Out:
# position in loop =  23
# this is in write mode
#
# position in loop =  53
# welcomethis is in write mode
#
# position in loop =  91
# welcomeZZZZZZZZZZZZZZZZZZZZZZZZZZZZZ
#
# position in loop =  126
# END!ZZZZZZZZZZZZZZZZZZZZZZZZZZZZZ
#
# position in loop =  130
# END!
# position in loop =  130
# -----------------------------------------------------------
# current position =  7
#  in write mode
# welcomethis is in write mode
# welcomeZZZZZZZZZZZZZZZZZZZZZZZZZZZZZ
# END!ZZZZZZZZZZZZZZZZZZZZZZZZZZZZZ
# END!
